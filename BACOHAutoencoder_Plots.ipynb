# %% [markdown]
# Notebook for the one-hot autoencoder

# %%
from communications import *
from model import *
import numpy as np
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2

# %%
import pickle

def save_obj(obj, name ):
    with open(name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def load_obj(name ):
    with open(name + '.pkl', 'rb') as f:
        return pickle.load(f)

# %%
from tensorflow.keras.models import load_model

encoder05,decoder05=load_model('AWGNOHEncoder_05.h5',custom_objects={'AWGN':AWGN}),load_model('AWGNOHDecoder_05.h5',custom_objects={'AWGN':AWGN},compile=False)
encoder1,decoder1=load_model('AWGNOHEncoder_1.h5',custom_objects={'AWGN':AWGN}),load_model('AWGNOHDecoder_1.h5',custom_objects={'AWGN':AWGN},compile=False)
encoder2,decoder2=load_model('AWGNOHEncoder_2.h5',custom_objects={'AWGN':AWGN}),load_model('AWGNOHDecoder_2.h5',custom_objects={'AWGN':AWGN},compile=False)
encoder1_BN,decoder1_BN=load_model('AWGNOHEncoder_1_BN.h5',custom_objects={'AWGN':AWGN}),load_model('AWGNOHDecoder_1_BN.h5',custom_objects={'AWGN':AWGN},compile=False)
encoder1_LN,decoder1_LN=load_model('AWGNOHEncoder_1_LN.h5',custom_objects={'AWGN':AWGN}),load_model('AWGNOHDecoder_1_LN.h5',custom_objects={'AWGN':AWGN},compile=False)
encoder1_BN_lr,decoder1_BN_lr=load_model('AWGNOHEncoder_BN_lr.h5',custom_objects={'AWGN':AWGN}),load_model('AWGNOHDecoder_BN_lr.h5',custom_objects={'AWGN':AWGN},compile=False)
encoder_mult,decoder_mult=load_model('AWGNOHEncoder_mult.h5',custom_objects={'multi_AWGN':multi_AWGN}),load_model('AWGNOHDecoder_mult.h5',custom_objects={'multi_AWGN':multi_AWGN},compile=False)


encoder_list,decoder_list=[encoder05,encoder1,encoder2,encoder1_BN,encoder1_LN,encoder1_BN_lr,encoder_mult],[decoder05,decoder1,decoder2,decoder1_BN,decoder1_LN,decoder1_BN_lr,decoder_mult]
multBER(encoder_list,decoder_list,'AWGN',[-1,0,0.5,1,2,3,4,5],save_params=True,params_name=['params_05_1_2.npy'],save_ber=True,ber_name=['ber_05.npy','ber_1.npy','ber_2.npy','ber_1_BN.npy','ber_1_LN.npy','ber_1_BN_lr.npy','ber_mult.npy'],plot_ber=True,points_per_value=[10**6],plot_legend=['0.5','1','2','BN','LN','lr','mult'],
        save_fig=True,fig_name='ALLModelsBER.pdf')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 100%|██████████| 8/8 [37:07<00:00, 278.46s/it]

# %%
from tensorflow.keras.models import load_model

#encoder_test,decoder_test=load_model('AWGNOHEncoder_test3.h5',custom_objects={'AWGN':AWGN,'Mish':Mish}),load_model('AWGNOHDecoder_test3.h5',custom_objects={'AWGN':AWGN,'Mish':Mish},compile=False)
encoder1,decoder1=load_model('BACOHEncoder_005.h5',custom_objects={'BAC_OH2':BAC_OH2}),load_model('BACOHDecoder_005.h5',custom_objects={'BAC_OH2':BSC},compile=False)
encoder2,decoder2=load_model('BACOHEncoder_02.h5',custom_objects={'BAC_OH2':BAC_OH2}),load_model('BACOHDecoder_02.h5',custom_objects={'BAC_OH2':BSC},compile=False)
encoder3,decoder3=load_model('BACOHEncoder_01.h5',custom_objects={'BAC_OH2':BSC_OH2}),load_model('BACOHDecoder_01.h5',custom_objects={'BAC_OH2':BSC},compile=False)
encoder4,decoder4=load_model('BACOHEncoder_01_bn.h5',custom_objects={'BAC_OH2':BSC_OH2}),load_model('BACOHDecoder_01_bn.h5',custom_objects={'BAC_OH2':BSC},compile=False)


encoder_list,decoder_list=[encoder1,encoder2,encoder3,encoder4],[decoder1,decoder2,decoder3,decoder4]
#encoder_list,decoder_list=[encoder1,encoder2],[decoder1,decoder2]
multBER(encoder_list,decoder_list,'BAC',[0.01,0.05,0.1,0.2,0.3,0.4],do_polar_MAP=True,save_params=False,params_name=['params_map2.npy'],
        save_ber=False,ber_name=['ber_test_map2.npy','ber_1_lr_map2.npy','ber_1_lr2_map2.npy','ber_map2.npy'],
        plot_ber=True,points_per_value=[200000],plot_legend=['0.05','0.2','0.1','0.1+bn','polar map'],
        save_fig=False,fig_name='ALLModelsBERwmap2.pdf')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 100%|██████████| 6/6 [14:20<00:00, 143.46s/it]

# %%
from tensorflow.keras.models import load_model

#encoder_test,decoder_test=load_model('AWGNOHEncoder_test3.h5',custom_objects={'AWGN':AWGN,'Mish':Mish}),load_model('AWGNOHDecoder_test3.h5',custom_objects={'AWGN':AWGN,'Mish':Mish},compile=False)
encoder1,decoder1=load_model('BACOHEncoder_005.h5',custom_objects={'BAC_OH2':BAC_OH2}),load_model('BACOHDecoder_005.h5',custom_objects={'BAC_OH2':BSC},compile=False)
encoder2,decoder2=load_model('BACOHEncoder_02.h5',custom_objects={'BAC_OH2':BAC_OH2}),load_model('BACOHDecoder_02.h5',custom_objects={'BAC_OH2':BSC},compile=False)
encoder3,decoder3=load_model('BACOHEncoder_01.h5',custom_objects={'BAC_OH2':BSC_OH2}),load_model('BACOHDecoder_01.h5',custom_objects={'BAC_OH2':BSC},compile=False)
encoder4,decoder4=load_model('BACOHEncoder_01_bn.h5',custom_objects={'BAC_OH2':BSC_OH2}),load_model('BACOHDecoder_01_bn.h5',custom_objects={'BAC_OH2':BSC},compile=False)


encoder_list,decoder_list=[encoder1,encoder2,encoder3,encoder4],[decoder1,decoder2,decoder3,decoder4]
#encoder_list,decoder_list=[encoder1,encoder2],[decoder1,decoder2]
multBER(encoder_list,decoder_list,'BAC',[0.01,0.05,0.1,0.2,0.3,0.4],do_polar_MAP=True,save_params=False,params_name=['params_map2.npy'],
        save_ber=False,ber_name=['ber_test_map2.npy','ber_1_lr_map2.npy','ber_1_lr2_map2.npy','ber_map2.npy'],
        plot_ber=True,points_per_value=[200000],plot_legend=['0.05','0.2','0.1','0.1+bn','polar map'],
        save_fig=False,fig_name='ALLModelsBERwmap2.pdf')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 100%|██████████| 6/6 [07:49<00:00, 78.32s/it]

# %% [markdown]
# q=0.07 (training q)

# %%
from tensorflow.keras.models import load_model

encoder1,decoder1=load_model('BACOHEncoder_01_bn.h5',custom_objects={'BAC_OH2':BSC_OH2}),load_model('BACOHDecoder_01_bn.h5',custom_objects={'BAC_OH2':BSC},compile=False)


encoder_list,decoder_list=[encoder1],[decoder1]
#encoder_list,decoder_list=[encoder1,encoder2],[decoder1,decoder2]
multBER(encoder_list,decoder_list,'BAC',[0.01,0.05,0.1,0.2,0.3,0.4],q_param=0.07,
        do_polar_MAP=True,do_enc_MAP=True,
        save_params=False,params_name=['params_map2.npy'],
        save_ber=False,ber_name=['ber_test_map2.npy','ber_1_lr_map2.npy','ber_1_lr2_map2.npy','ber_map2.npy'],
        plot_ber=True,points_per_value=[200000],plot_legend=['encoder+decoder','polar+map','enc+map'],
        save_fig=False,fig_name='ALLModelsBERwmap2.pdf')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 100%|██████████| 6/6 [09:44<00:00, 97.38s/it]

# %% [markdown]
# q=0.1

# %%
from tensorflow.keras.models import load_model

encoder1,decoder1=load_model('BACOHEncoder_01_bn.h5',custom_objects={'BAC_OH2':BSC_OH2}),load_model('BACOHDecoder_01_bn.h5',custom_objects={'BAC_OH2':BSC},compile=False)


encoder_list,decoder_list=[encoder1],[decoder1]
#encoder_list,decoder_list=[encoder1,encoder2],[decoder1,decoder2]
multBER(encoder_list,decoder_list,'BAC',[0.01,0.05,0.1,0.2,0.3,0.4],q_param=0.1,
        do_polar_MAP=True,do_enc_MAP=True,
        save_params=False,params_name=['params_map2.npy'],
        save_ber=False,ber_name=['ber_test_map2.npy','ber_1_lr_map2.npy','ber_1_lr2_map2.npy','ber_map2.npy'],
        plot_ber=True,points_per_value=[200000],plot_legend=['encoder+decoder','polar+map','enc+map'],
        save_fig=False,fig_name='ALLModelsBERwmap2.pdf')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 100%|██████████| 6/6 [09:39<00:00, 96.50s/it]

# %% [markdown]
# q=0.2

# %%
from tensorflow.keras.models import load_model

encoder1,decoder1=load_model('BACOHEncoder_01_bn.h5',custom_objects={'BAC_OH2':BAC_OH2}),load_model('BACOHDecoder_01_bn.h5',custom_objects={'BAC_OH2':BAC_OH2},compile=False)
encoder2,decoder2=load_model('BACOHEncoder_005_bn.h5',custom_objects={'BAC_OH2':BAC_OH2}),load_model('BACOHDecoder_005_bn.h5',custom_objects={'BAC_OH2':BAC_OH2},compile=False)
encoder3,decoder3=load_model('BACOHEncoder_01_test.h5',custom_objects={'BAC_OH2':BAC_OH2,'Mish':Mish}),load_model('BACOHDecoder_01_test.h5',custom_objects={'BAC_OH2':BAC_OH2,'Mish':Mish},compile=False)


encoder_list,decoder_list=[encoder1,encoder2,encoder3],[decoder1,decoder2,decoder3]
#encoder_list,decoder_list=[encoder1,encoder2],[decoder1,decoder2]
multBER(encoder_list,decoder_list,'BAC',[0.01,0.05,0.1,0.2,0.3,0.4],q_param=0.07,
        do_polar_MAP=True,enc_MAP_ind=[0,1,2],
        save_params=False,params_name=['params_map2.npy'],
        save_ber=False,ber_name=['ber_test_map2.npy','ber_1_lr_map2.npy','ber_1_lr2_map2.npy','ber_map2.npy'],
        plot_ber=True,points_per_value=[200000],plot_legend=['0.1+bn','0.05+bn','0.1 test','polar+map','0.1 bn map','0.05 bn map','0.1 test map'],
        save_fig=False,fig_name='ALLModelsBERwmap2.pdf')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 100%|██████████| 6/6 [19:06<00:00, 191.17s/it]
