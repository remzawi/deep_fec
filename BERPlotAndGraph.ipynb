# %% [markdown]
# Compute and plot BER from saved NN models or deterministic decoder

# %%
from communications import *
from model import *
import numpy as np
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# MAP

# %%
computePOLARBER(apply_MAP_AWGN,'AWGN',[-1,0,1,2,3,4],one_hot=False,save_params=False,save_ber=False)
