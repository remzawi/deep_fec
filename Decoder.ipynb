# %% [markdown]
# Notebook to test the one-hot decoder

# %% [markdown]
# Some imports and autoreload

# %%
from communications import *
from model import *
import numpy as np
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# AWGN

# %% [markdown]
# Training set

# %%
X_train,y_train=createTrainingDatasetDecoder(BPSK=True,one_hot=True)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (256, 16)
# (256, 256)

# %%
model2=create_model(5*256,1)

# %%
checkpoint=tf.keras.callbacks.ModelCheckpoint('AWGNOHDecoder2.tf',monitor='loss',save_best_only=True)
history=model2.fit(x=X_train,y=y_train,batch_size=256,epochs=2**10,callbacks=[checkpoint],verbose=1)
# Out:
# Epoch 1/1024
# 1/1 [==============================] - 0s 22ms/step - loss: 6.1927 - ber_metric_oh: 0.0078 - acc: 0.0000e+00
# Epoch 2/1024
# 1/1 [==============================] - 0s 22ms/step - loss: 5.5088 - ber_metric_oh: 0.0070 - acc: 0.0156
# Epoch 3/1024
# 1/1 [==============================] - 0s 22ms/step - loss: 4.7183 - ber_metric_oh: 0.0068 - acc: 0.0664
# Epoch 4/1024
# 1/1 [==============================] - 0s 21ms/step - loss: 3.9786 - ber_metric_oh: 0.0058 - acc: 0.1680
# Epoch 5/1024
# 1/1 [==============================] - 0s 22ms/step - loss: 3.4007 - ber_metric_oh: 0.0049 - acc: 0.2812
# Epoch 6/1024
# 1/1 [==============================] - 0s 21ms/step - loss: 2.9229 - ber_metric_oh: 0.0044 - acc: 0.3672
# Epoch 7/1024
# 1/1 [==============================] - 0s 22ms/step - loss: 2.4938 - ber_metric_oh: 0.0029 - acc: 0.4961
# Epoch 8/1024
# 1/1 [==============================] - 0s 21ms/step - loss: 2.0285 - ber_metric_oh: 0.0021 - acc: 0.6289
# Epoch 9/1024
# ...

# %%
model.save('awgntest1.tf')
# Out:
# WARNING:tensorflow:Skipping full serialization of Keras layer <model.AWGN object at 0x7f20be9cd190>, because it is not built.
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:1817: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: awgntest1.tf/assets
